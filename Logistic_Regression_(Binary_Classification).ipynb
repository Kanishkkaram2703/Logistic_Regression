# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
plt.scatter(df.Glucose, df.Age, marker = '+', color = "red")

# %%
from sklearn.model_selection import train_test_split

# %%
 X_train, X_test, y_train, y_test = train_test_split(df[['Age']], df.Glucose, test_size = 0.1)

# %%
X_test
# Out:
#      Age
# 232   22
# 454   24
# 552   66
# 224   26
# 12    57
# ..   ...
# 712   38
# 88    43
# 155   36
# 588   52
# 638   32
#
# [77 rows x 1 columns]

# %%
model = linear_model.LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.predict(X_test)
# Out:
# array([112.33539356, 113.83551964, 145.33816741, 115.33564573,
#        138.58760003, 114.58558268, 116.83577181, 111.58533052,
#        111.58533052, 116.08570877, 115.33564573, 128.08671744,
#        113.83551964, 111.58533052, 120.58608702, 114.58558268,
#        113.83551964, 112.33539356, 112.33539356, 121.33615006,
#        130.33690657, 113.0854566 , 128.08671744, 131.08696961,
#        120.58608702, 141.5878522 , 117.58583485, 116.08570877,
#        113.83551964, 143.83804132, 116.08570877, 133.33715873,
#        136.3374109 , 112.33539356, 113.83551964, 116.83577181,
#        117.58583485, 117.58583485, 111.58533052, 138.58760003,
#        114.58558268, 115.33564573, 111.58533052, 112.33539356,
#        118.33589789, 120.58608702, 117.58583485, 119.08596094,
#        121.33615006, 113.0854566 , 112.33539356, 112.33539356,
#        140.83778915, 125.08646527, 113.0854566 , 112.33539356,
#        115.33564573, 125.83652831, 121.33615006, 119.83602398,
#        113.83551964, 120.58608702, 126.58659136, 122.0862131 ,
#        118.33589789, 126.58659136, 122.0862131 , 114.58558268,
#        121.33615006, 115.33564573, 117.58583485, 117.58583485,
#        124.33640223, 128.08671744, 122.83627615, 134.83728482,
#        119.83602398])

# %%
model.score(X_test, y_test) # score decribe about the accuracy of the model
# Out:
# 0.0035985483607261504

# %% [raw]
# Due to large no.of dataset we get mostly negative values or lesser values

# %%
# probsbility of the x test
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_classification
clf = LogisticRegression()
clf.fit(X_train, y_train)

# Predict probabilities
proba = clf.predict_proba(X_test)
proba
# Out:
# C:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# array([[1.01914327e-02, 1.53209313e-03, 2.28862331e-03, ...,
#         7.49265847e-04, 1.82619447e-03, 2.28862331e-03],
#        [9.93857015e-03, 1.65602936e-03, 2.14084028e-03, ...,
#         1.00299746e-03, 1.81433426e-03, 2.14084028e-03],
#        [4.39005740e-04, 6.35027526e-04, 3.94527741e-05, ...,
#         3.43183156e-02, 1.18461565e-04, 3.94527741e-05],
#        ...,
#        [6.34921203e-03, 1.96168451e-03, 1.06538825e-03, ...,
#         4.28693737e-03, 1.29599374e-03, 1.06538825e-03],
#        [1.93205197e-03, 1.35982101e-03, 2.32368447e-04, ...,
#         1.64455331e-02, 4.57672461e-04, 2.32368447e-04],
#        [7.75432159e-03, 1.95013527e-03, 1.41412991e-03, ...,
#         2.77856560e-03, 1.52497827e-03, 1.41412991e-03]])
